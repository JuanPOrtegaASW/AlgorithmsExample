# %% [markdown]
# # Data Exploration

# %% [markdown]
# Hey! During this first step, please, take a look at the data set and just explore it, find the types of each column and try to find interesting things. Don't worry about data cleaning. Just exploration for now.
# You can answer the following questions:
# - How many columns there are
# - The type of each column
# - The different values that a column can take
# - Which do you think are the most important columns? If we are looking at the overall score.
#
# Go wild! (Remember, so far, only exploration).

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('Saber_11__2019-2.csv')
df
# Out:
# C:\Users\jortega\AppData\Local\Temp\ipykernel_10496\416583644.py:1: DtypeWarning: Columns (76,78) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('Saber_11__2019-2.csv')
#        ESTU_TIPODOCUMENTO ESTU_NACIONALIDAD ESTU_GENERO  \
# 0                      TI          COLOMBIA           M
# 1                      TI          COLOMBIA           M
# 2                      TI          COLOMBIA           M
# 3                      TI          COLOMBIA           M
# 4                      TI          COLOMBIA           M
# ...                   ...               ...         ...
# 546207                 CC          COLOMBIA           M
# 546208                 TI          COLOMBIA           M
# 546209                 TI          COLOMBIA           M
# 546210                 TI          COLOMBIA           M
# 546211                 TI          COLOMBIA           M
#
#           ESTU_FECHANACIMIENTO  PERIODO  ESTU_CONSECUTIVO ESTU_ESTUDIANTE  \
# ...

# %%
pib =pd.read_excel('anexo-2021-preliminar-PIB-total-por-departamento.xlsx',sheet_name='Cuadro 3',header=8,nrows=34)
pib = pib[pib['DEPARTAMENTOS']!='COLOMBIA']
pib
# Out:
#     Código Departamento (DIVIPOLA)  \
# 1                             91.0
# 2                              5.0
# 3                             81.0
# 4                              8.0
# 5                             11.0
# 6                             13.0
# 7                             15.0
# 8                             17.0
# 9                             18.0
# 10                            85.0
# 11                            19.0
# 12                            20.0
# 13                            27.0
# 14                            23.0
# 15                            25.0
# 16                            94.0
# 17                            95.0
# 18                            41.0
# 19                            44.0
# 20                            47.0
# 21                            50.0
# 22                            52.0
# 23                            54.0
# 24                            86.0
# 25                            63.0
# ...

# %%
cols=list(df.columns)
print(cols)
# Out:
# ['ESTU_TIPODOCUMENTO', 'ESTU_NACIONALIDAD', 'ESTU_GENERO', 'ESTU_FECHANACIMIENTO', 'PERIODO', 'ESTU_CONSECUTIVO', 'ESTU_ESTUDIANTE', 'ESTU_TIENEETNIA', 'ESTU_PAIS_RESIDE', 'ESTU_ETNIA', 'ESTU_DEPTO_RESIDE', 'ESTU_COD_RESIDE_DEPTO', 'ESTU_MCPIO_RESIDE', 'ESTU_COD_RESIDE_MCPIO', 'FAMI_ESTRATOVIVIENDA', 'FAMI_PERSONASHOGAR', 'FAMI_CUARTOSHOGAR', 'FAMI_EDUCACIONPADRE', 'FAMI_EDUCACIONMADRE', 'FAMI_TRABAJOLABORPADRE', 'FAMI_TRABAJOLABORMADRE', 'FAMI_TIENEINTERNET', 'FAMI_TIENESERVICIOTV', 'FAMI_TIENECOMPUTADOR', 'FAMI_TIENELAVADORA', 'FAMI_TIENEHORNOMICROOGAS', 'FAMI_TIENEAUTOMOVIL', 'FAMI_TIENEMOTOCICLETA', 'FAMI_TIENECONSOLAVIDEOJUEGOS', 'FAMI_NUMLIBROS', 'FAMI_COMELECHEDERIVADOS', 'FAMI_COMECARNEPESCADOHUEVO', 'FAMI_COMECEREALFRUTOSLEGUMBRE', 'FAMI_SITUACIONECONOMICA', 'ESTU_DEDICACIONLECTURADIARIA', 'ESTU_DEDICACIONINTERNET', 'ESTU_HORASSEMANATRABAJA', 'ESTU_TIPOREMUNERACION', 'COLE_CODIGO_ICFES', 'COLE_COD_DANE_ESTABLECIMIENTO', 'COLE_NOMBRE_ESTABLECIMIENTO', 'COLE_GENERO', 'COLE_NAT
# ...

# %%
datatypes = df.dtypes
datatypes
# Out:
# ESTU_TIPODOCUMENTO           object
# ESTU_NACIONALIDAD            object
# ESTU_GENERO                  object
# ESTU_FECHANACIMIENTO         object
# PERIODO                       int64
#                              ...
# ESTU_INSE_INDIVIDUAL         object
# ESTU_NSE_INDIVIDUAL          object
# ESTU_NSE_ESTABLECIMIENTO    float64
# ESTU_ESTADOINVESTIGACION     object
# ESTU_GENERACION-E            object
# Length: 82, dtype: object

# %%
missing_values=np.where(pd.isnull(df))
missing_values
# Out:
# (array([     5,      5,      5, ..., 546167, 546167, 546167], dtype=int64),
#  array([18, 22, 30, ..., 30, 32, 35], dtype=int64))

# %%
cols[18]
# Out:
# 'FAMI_EDUCACIONMADRE'

# %%
num_of_misses = np.zeros(len(cols))
unique, counts = np.unique(missing_values[1], return_counts=True)
missing_cols = []
for index in unique:
    missing_cols.append(cols[index])
fig, ax = plt.subplots(figsize=(12, 6))
sns.barplot(x=missing_cols,y=counts)
ax.set_xticklabels(chart.get_xticklabels(), rotation=90, horizontalalignment='right')
plt.show()

# %%
punt_por_dept = df.groupby(['ESTU_DEPTO_RESIDE']).mean()['PUNT_GLOBAL']
sorted_punt_por_dept = punt_por_dept.sort_values(ascending = True)
punt_por_dept = punt_por_dept.drop('EXTRANJERO')
punt_por_dept
# Out:
# C:\Users\jortega\AppData\Local\Temp\ipykernel_18104\605845794.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   punt_por_dept = df.groupby(['ESTU_DEPTO_RESIDE']).mean()['PUNT_GLOBAL']
# ESTU_DEPTO_RESIDE
# AMAZONAS           213.061818
# ANTIOQUIA          241.928208
# ARAUCA             241.085740
# ATLANTICO          241.557693
# BOGOTÁ             266.450622
# BOLIVAR            227.533886
# BOYACA             261.560461
# CALDAS             246.178376
# CAQUETA            233.480250
# CASANARE           246.739029
# CAUCA              228.094707
# CESAR              238.436502
# CHOCO              200.808793
# CORDOBA            235.604532
# CUNDINAMARCA       253.136341
# GUAINIA            222.988806
# GUAVIARE           224.022616
# HUILA              250.018881
# ...

# %%
sns.scatterplot(x=pib[2019],y=punt_por_dept.tolist())
# Out:
# <AxesSubplot: xlabel='2019'>

# %%
np.corrcoef(x=pib[2019],y=punt_por_dept.tolist())
# Out:
# array([[1.        , 0.63107992],
#        [0.63107992, 1.        ]])
